# %%
# image = ...
# for r,c in image:
#     if closer to blue:
#         add a beat
#     elif closer to green:
#         add a bit of melody
#     elif closer to red:
#         add a chord (tone with harmonics)
#     else:
# from PIL import Image
# img = Image.open('Tigers Jaw.jpg','r')
# pix_val = list(img.getdata())
# pix_sum = len(pix_val)
# print(pix_val[0])
# Out:
# (255, 76, 1)

# %%
# import IPython.display
# import random
# wave = []
# Max_value = 1
# for x in range(pix_sum):
#     rgb = pix_val[x]
#     red = min(rgb) // 10
#     wave.append(min(x>>3 & x >> red & x<<6, Max_value))
    
# #wave = [x & x >> 8 for x in range(100000)]
# IPython.display.Audio(data=wave, rate=44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
#import soundfile as sf
import numpy as np

# Get example audio file
filename = "Es Dur Short.mp3"
y, sr = librosa.core.load(filename)
print(len(y))
# data, samplerate = sf.read(filename, dtype='float32')
# data = data.T
# print(data)
#data_22k = librosa.resample(data, samplerate, 22050)
# Out:
# ---------------------------------------------------------------------------
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-7-610ad1b6b36a> in <module>()
#       5 # Get example audio file
#       6 filename = "Es Dur Short.mp3"
# ----> 7 y, sr = librosa.core.load(filename)
#       8 print(len(y))
#       9 # data, samplerate = sf.read(filename, dtype='float32')
#
# C:\Users\aliu\Anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     110
#     111     y = []
# --> 112     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     113         sr_native = input_file.samplerate
#     114         n_channels = input_file.channels
#
# C:\Users\aliu\Anaconda3\lib\site-packages\audioread\__init__.py in audio_open(path)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %%
print(min(y), max(y))
#Tribute: -1.1062168 1.103909
#Pata's Nap: -0.7218019 0.67863786
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-99c0ed916925> in <module>()
# ----> 1 print(min(y), max(y))
#       2 #Tribute: -1.1062168 1.103909
#       3 #Pata's Nap: -0.7218019 0.67863786
#
# NameError: name 'y' is not defined

# %%
from PIL import Image, ImageColor
import math

height = int(math.sqrt(len(y)))
width = len(y) // height
# im = Image.new('1', (1,1)) # create the Image of size 1 pixel - width, height
# im.putpixel((0,0), ImageColor.getcolor('black', '1')) # or whatever color you wish
# im.save('simplePixel.png')
img = Image.new('RGB', (width, height))
minimum = min(y)
maxiumum = max(y)
available_range = max(y) - min(y)
for r in range(height):
    for c in range(width):
        moment = y[c + (r * width)]
        if (moment - minimum) > (available_range * 2) / 3:
            color = 'red'
        elif (moment - minimum) > available_range / 3:
            color = 'green'
        else:
            color = 'blue'
        img.putpixel((c,r), ImageColor.getcolor(color, 'RGB')) # or whatever color you wish

# %%
#print(img)
img.save('Song_image.jpg')

# %%
arr = np.array(y)
librosa.output.write_wav('pic-to-song.wav', arr, sr)

# %%
img2 = Image.open('Song_image.jpg','r')
pix_val = list(img2.getdata())
pix_sum = len(pix_val)
